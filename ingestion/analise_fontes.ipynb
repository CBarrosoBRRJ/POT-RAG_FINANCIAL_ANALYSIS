# %% [markdown]
# # Análise das Fontes de Dados - BCB
# Este notebook serve para explorar as APIs do Banco Central do Brasil antes da automação no script `load_bcb.py`.

# %%
import requests
import pandas as pd

# SELIC

url = "https://api.bcb.gov.br/dados/serie/bcdata.sgs.1178/dados?dataInicial=01/01/2025"
response = requests.get(url)
data = response.json()

df = pd.DataFrame(data)
df.head(365)
# Out:
#            data  valor
# 0    02/01/2025  12.15
# 1    03/01/2025  12.15
# 2    06/01/2025  12.15
# 3    07/01/2025  12.15
# 4    08/01/2025  12.15
# ..          ...    ...
# 300  13/03/2026  14.90
# 301  16/03/2026  14.90
# 302  17/03/2026  14.90
# 303  18/03/2026  14.90
# 304  19/03/2026  14.65
#
# [305 rows x 2 columns]
